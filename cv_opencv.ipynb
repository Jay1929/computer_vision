# %% [markdown]
# <a href="https://colab.research.google.com/github/Jay1929/computer_vision/blob/main/cv_opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow
image = cv2.imread('/content/cat_image.jpeg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=277x182>

# %%
print('Shape:', image.shape)
# 182 => height
# 277 => width
# 3 =>  color channels(Red, Green, Blue)
print('height:', image.shape[0])
print('width:', image.shape[1])
print('channels:', image.shape[2])
# Out:
# Shape: (182, 277, 3)
# height: 182
# width: 277
# channels: 3

# %%
(b, g, r) = image[100, 50]
print('Blue:', b, 'Green:', g, 'Red:', r)
# Out:
# Blue: 107 Green: 137 Red: 184

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=277x182>

# %%
resized = cv2.resize(gray, (300, 300))
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=L size=300x300>

# %%
cropped = gray[100:300, 150:350]
cv2_imshow(cropped)
# Out:
# <PIL.Image.Image image mode=L size=127x82>

# %%
rotated = cv2.rotate(gray, cv2.ROTATE_180)
cv2_imshow(rotated)
# Out:
# <PIL.Image.Image image mode=L size=277x182>

# %%
flipped = cv2.flip(gray, 1)
cv2_imshow(flipped)
# Out:
# <PIL.Image.Image image mode=L size=277x182>

# %%
cv2.imwrite('cropped_cat.jpeg', cropped)
# Out:
# True

# %%
cropped_cat = cv2.imread('/content/flipped_cat.jpeg')
cv2_imshow(cropped)
# Out:
# <PIL.Image.Image image mode=L size=127x82>

# %% [markdown]
# Opencv video streaming codes

# %%
print('Hello World!')

import cv2

cap = cv2.VideoCapture(0)

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

while True:
    success, frame = cap.read()

    if not success:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray, 1.5, 4)

    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)


    cv2.imshow('Real-time face detection', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break



cap.release()
cv2.destroyAllWindows()



#=======================================================


# import cv2

# cap = cv2.VideoCapture(0)


# while True:
#     success, frame = cap.read() # True, False | Boolean

#     if not success:
#         break

#     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#     blurred = cv2.GaussianBlur(frame, (15, 15), 0)
#     edges1 = cv2.Canny(frame, 100, 200)
#     edges2 = cv2.Canny(frame, 50, 250)

#     flipped = cv2.flip(frame, 1)

#     # cv2.imshow("Original", frame)
#     # cv2.imshow('Gray:', gray)
#     # cv2.imshow("Blurred:", blurred) # Noise

#     # cv2.imshow("Edges1:", edges1)
#     # cv2.imshow("Edges2:", edges2)

#     cv2.imshow('flipped:', flipped)


#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break


# cap.release()
# cv2.destroyAllWindows()
